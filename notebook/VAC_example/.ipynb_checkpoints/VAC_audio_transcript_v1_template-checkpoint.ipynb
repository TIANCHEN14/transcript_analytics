# %%
import sounddevice as sd
import numpy as np
from transformers import WhisperProcessor, WhisperForConditionalGeneration
import torchaudio
import torch

# transcribing audio that is 
def transcribe_audio(audio_array, model, processor):
    # transcrible audio using whisper model
    #print("transcribe function called")

    #print("Array shape : " , audio_array.shape)
    #print("Array type : " , audio_array.dtype)

    # MAKE SURE THE DATA IS IN AN 1D ARRAY BEFORE PASS IT IN
    inputs = processor(audio_array , sampling_rate = 16000 , return_tensors = 'pt').input_features
    inputs = inputs.to('cuda')
    
    #print("start to transcrpting")
    
    # generated new ids base on the inputs
    with torch.no_grad():
        output_ids = model.generate(inputs)
    
    # Decode tokens
    output_text = processor.batch_decode(output_ids, skip_special_tokens = True)
    
    return output_text[0]
    

def audio_callback(indata, frames, time, status):
    if status:
        print(status)
    # Append the incoming audio data to the global list
    global audio_data
    audio_data.append(indata.copy())  

def record_audio(duration = 5 , model = None, processor = None):
    # define global variable for all audio samples
    global audio_data
    audio_data = []
    
    # define sampling rate
    sampling_rate = 16000
    channels = 1 # mono channels
    
    # Start the stream
    with sd.InputStream(callback=audio_callback, samplerate=sampling_rate, channels=channels):
        sd.sleep(duration * 1000)  # Sleep for the duration of the recording


    audio_array = np.concatenate(audio_data)
    audio_array = audio_array.squeeze()
    transcription = transcribe_audio(audio_array, model, processor)
    
    sd.wait()
    return transcription

    #return audio_array

# %%
model = WhisperForConditionalGeneration.from_pretrained("openai/whisper-medium.en").to('cuda')
processor = WhisperProcessor.from_pretrained("openai/whisper-medium.en")

sd.default.samplerate = 16000
sd.default.device = 1

# %%
while True:
    #print("Starting a new 10-second recording...")
    transcription = record_audio(5, model=model, processor=processor)
    print("Recording completed. Transcription:", transcription)
    print("###################################################################################################################")
    #print("Waiting for the next recording...")
    sd.sleep(10)  # Delay before the next recording
# Out:
# C:\Users\chent\AppData\Local\Programs\Python\Python311\Lib\site-packages\transformers\models\whisper\modeling_whisper.py:697: UserWarning: 1Torch was not compiled with flash attention. (Triggered internally at ..\aten\src\ATen\native\transformers\cuda\sdp_utils.cpp:263.)
#   attn_output = torch.nn.functional.scaled_dot_product_attention(
# Recording completed. Transcription:  Trial
# ###################################################################################################################
# Recording completed. Transcription:  .
# ###################################################################################################################
# Recording completed. Transcription:  Trial
# ###################################################################################################################
# Recording completed. Transcription:  .
# ###################################################################################################################
# Recording completed. Transcription:  Trial
# ###################################################################################################################
# Recording completed. Transcription:  .
# ###################################################################################################################
# Recording completed. Transcription:  Trial
# ###################################################################################################################
# Recording completed. Transcription:  Trial
# ###################################################################################################################
# Recording completed. Transcription:  Try.
# ###################################################################################################################
# Recording completed. Transcription:  you
# ###################################################################################################################
# Recording completed. Transcription:  .
# ###################################################################################################################
# Recording completed. Transcription:  Trial
# ###################################################################################################################
# Recording completed. Transcription:  .
# ###################################################################################################################
# Recording completed. Transcription:  .
# ###################################################################################################################
# Recording completed. Transcription:  Trial
# ###################################################################################################################
# Recording completed. Transcription:  Trial
# ###################################################################################################################
# Recording completed. Transcription:  Got me off the radar.
# ###################################################################################################################
# Recording completed. Transcription:  Trial
# ###################################################################################################################
# Recording completed. Transcription:  It's going to be about 10 away right here.
# ###################################################################################################################
# Recording completed. Transcription:  Trial
# ###################################################################################################################
# Recording completed. Transcription:  .
# ###################################################################################################################
# Recording completed. Transcription:  Trial
# ###################################################################################################################
# Recording completed. Transcription:  Trial
# ###################################################################################################################
# Recording completed. Transcription:  .
# ###################################################################################################################
# Recording completed. Transcription:  Ryle?
# ###################################################################################################################
# Recording completed. Transcription:  going to be a lot of pace laps they're going to work on pit road here.
# ###################################################################################################################
# Recording completed. Transcription:  Is that it, Joe?
# ###################################################################################################################
# Recording completed. Transcription:  trial
# ###################################################################################################################
# Recording completed. Transcription:  Do I have to go?
# ###################################################################################################################
# Recording completed. Transcription:  Oh, I don't think that was me.
# ###################################################################################################################
# Recording completed. Transcription:  But
# ###################################################################################################################
# Recording completed. Transcription:  Channel 3 is any better if it is, then maybe we make it our new one.
# ###################################################################################################################
# Recording completed. Transcription:  back there.
# ###################################################################################################################
# Recording completed. Transcription:  Trial.
# ###################################################################################################################
# Recording completed. Transcription:  Thank you.
# ###################################################################################################################
# Recording completed. Transcription:  Trial
# ###################################################################################################################
# Recording completed. Transcription:  .
# ###################################################################################################################
# Recording completed. Transcription:  Draw
# ###################################################################################################################
# Recording completed. Transcription:  you
# ###################################################################################################################
# Recording completed. Transcription:  as you can here.
# ###################################################################################################################
# Recording completed. Transcription:  you
# ###################################################################################################################
# Recording completed. Transcription:  Cars at pit road speed, looking at sitting gear 38.26 to red on pit road today.
# ###################################################################################################################
# Recording completed. Transcription:  Trial
# ###################################################################################################################
# Recording completed. Transcription:  .
# ###################################################################################################################
# Recording completed. Transcription:  Try.
# ###################################################################################################################
# Recording completed. Transcription:  you
# ###################################################################################################################
# Recording completed. Transcription:  Draw
# ###################################################################################################################
# Recording completed. Transcription:  you
# ###################################################################################################################
# Recording completed. Transcription:  Trial
# ###################################################################################################################
# Recording completed. Transcription:  .
# ###################################################################################################################
# Recording completed. Transcription:  Try it.
# ###################################################################################################################
# Recording completed. Transcription:  you
# ###################################################################################################################
# Recording completed. Transcription:  Trial
# ###################################################################################################################
# Recording completed. Transcription:  .
# ###################################################################################################################
# Recording completed. Transcription:  Oof! Trial?
# ###################################################################################################################
# Recording completed. Transcription:  .
# ###################################################################################################################
# Recording completed. Transcription:  Trial
# ###################################################################################################################
# Recording completed. Transcription:  .
# ###################################################################################################################
# Recording completed. Transcription:  Trial
# ###################################################################################################################
# Recording completed. Transcription:  .
# ###################################################################################################################
# Recording completed. Transcription:  Trial
# ###################################################################################################################
# Recording completed. Transcription:  .
# ###################################################################################################################
# Recording completed. Transcription:  Trial
# ###################################################################################################################
# Recording completed. Transcription:  Trial
# ###################################################################################################################
# Recording completed. Transcription:  .
# ###################################################################################################################
# Recording completed. Transcription:  .
# ###################################################################################################################
# Recording completed. Transcription:  Trial
# ###################################################################################################################
# Recording completed. Transcription:  Trial
# ###################################################################################################################
# Recording completed. Transcription:  .
# ###################################################################################################################
# Recording completed. Transcription:  Trial
# ###################################################################################################################
# Recording completed. Transcription:  .
# ###################################################################################################################
# Recording completed. Transcription:  Draw the line.
# ###################################################################################################################
# Recording completed. Transcription:  you
# ###################################################################################################################
# Recording completed. Transcription:  Trial
# ###################################################################################################################
# Recording completed. Transcription:  .
# ###################################################################################################################
# Recording completed. Transcription:  Trial
# ###################################################################################################################
# Recording completed. Transcription:  .
# ###################################################################################################################
# Recording completed. Transcription:  Trial
# ###################################################################################################################
# Recording completed. Transcription:  .
# ###################################################################################################################
# Recording completed. Transcription:  Trial
# ###################################################################################################################
# Recording completed. Transcription:  Check, check.
# ###################################################################################################################
# Recording completed. Transcription:  Trial
# ###################################################################################################################
# Recording completed. Transcription:  .
# ###################################################################################################################
# Recording completed. Transcription:  Still got you here. Probably gonna be still about four
# ###################################################################################################################
# Recording completed. Transcription:  of life.
# ###################################################################################################################
# Recording completed. Transcription:  Keep saving until... ...Trial.
# ###################################################################################################################
# Recording completed. Transcription:  .
# ###################################################################################################################
# Recording completed. Transcription:  Oh?
# ###################################################################################################################
# Recording completed. Transcription:  Trial
# ###################################################################################################################
# Recording completed. Transcription:  .
# ###################################################################################################################
# Recording completed. Transcription:  Trial
# ###################################################################################################################
# Recording completed. Transcription:  .
# ###################################################################################################################
# Recording completed. Transcription:  Trial
# ###################################################################################################################
# Recording completed. Transcription:  Trial
# ###################################################################################################################
# Recording completed. Transcription:  .
# ###################################################################################################################
# Recording completed. Transcription:  Trials
# ###################################################################################################################
# Recording completed. Transcription:  you
# ###################################################################################################################
# Recording completed. Transcription:  .
# ###################################################################################################################
# Recording completed. Transcription:  Trial
# ###################################################################################################################
# Recording completed. Transcription:  .
# ###################################################################################################################
# Recording completed. Transcription:  .
# ###################################################################################################################
# Recording completed. Transcription:  Trial
# ###################################################################################################################
# Recording completed. Transcription:  Trials
# ###################################################################################################################
# Recording completed. Transcription:  you
# ###################################################################################################################
# Recording completed. Transcription:  Trial
# ###################################################################################################################
# Recording completed. Transcription:  .
# ###################################################################################################################
# Recording completed. Transcription:  Trial
# ###################################################################################################################
# Recording completed. Transcription:  .
# ###################################################################################################################
# Recording completed. Transcription:  Trial
# ###################################################################################################################
# Recording completed. Transcription:  To
# ###################################################################################################################
# Recording completed. Transcription:  Hello?
# ###################################################################################################################
# Recording completed. Transcription:  Trial
# ###################################################################################################################
# Recording completed. Transcription:  Trial
# ###################################################################################################################
# Recording completed. Transcription:  .
# ###################################################################################################################
# Recording completed. Transcription:  Trial.
# ###################################################################################################################
# Recording completed. Transcription:  you
# ###################################################################################################################
# Recording completed. Transcription:  Oh?
# ###################################################################################################################
# Recording completed. Transcription:  .
# ###################################################################################################################
# Recording completed. Transcription:  Trial
# ###################################################################################################################
# Recording completed. Transcription:  .
# ###################################################################################################################
# Recording completed. Transcription:  Try it.
# ###################################################################################################################
# Recording completed. Transcription:  you
# ###################################################################################################################
# Recording completed. Transcription:  Trial
# ###################################################################################################################
# Recording completed. Transcription:  .
# ###################################################################################################################
# Recording completed. Transcription:  Trial
# ###################################################################################################################
# Recording completed. Transcription:  Trial
# ###################################################################################################################
# Recording completed. Transcription:  .
# ###################################################################################################################
# Recording completed. Transcription:  Trial
# ###################################################################################################################
# Recording completed. Transcription:  Trial
# ###################################################################################################################
# Recording completed. Transcription:  .
# ###################################################################################################################
# Recording completed. Transcription:  Well...
# ###################################################################################################################
# Recording completed. Transcription:  Trial
# ###################################################################################################################
# Recording completed. Transcription:  .
# ###################################################################################################################
# Recording completed. Transcription:  Trial
# ###################################################################################################################
# Recording completed. Transcription:  Keep saving.
# ###################################################################################################################
# Recording completed. Transcription:  Trial
# ###################################################################################################################
# Recording completed. Transcription:  .
# ###################################################################################################################
# Recording completed. Transcription:  Trial
# ###################################################################################################################
# Recording completed. Transcription:  Trial
# ###################################################################################################################
# Recording completed. Transcription:  .
# ###################################################################################################################
# Recording completed. Transcription:  Trial
# ###################################################################################################################
# Recording completed. Transcription:  .
# ###################################################################################################################
# Recording completed. Transcription:  Trial
# ###################################################################################################################
# Recording completed. Transcription:  .
# ###################################################################################################################
# Recording completed. Transcription:  Trial
# ###################################################################################################################
# Recording completed. Transcription:  Trials
# ###################################################################################################################
# Recording completed. Transcription:  you
# ###################################################################################################################
# Recording completed. Transcription:  Trial
# ###################################################################################################################
# Recording completed. Transcription:  .
# ###################################################################################################################
# Recording completed. Transcription:  Trial
# ###################################################################################################################
# Recording completed. Transcription:  Try
# ###################################################################################################################
# Recording completed. Transcription:  you
# ###################################################################################################################
# Recording completed. Transcription:  Trial
# ###################################################################################################################
# Recording completed. Transcription:  Trial
# ###################################################################################################################
# Recording completed. Transcription:  .
# ###################################################################################################################
# Recording completed. Transcription:  .
# ###################################################################################################################
# Recording completed. Transcription:  Trial
# ###################################################################################################################
# Recording completed. Transcription:  Trial
# ###################################################################################################################
# Recording completed. Transcription:  .
# ###################################################################################################################
# Recording completed. Transcription:  Try it.
# ###################################################################################################################
# Recording completed. Transcription:  you
# ###################################################################################################################
# Recording completed. Transcription:  trial.
# ###################################################################################################################
# Recording completed. Transcription:  .
# ###################################################################################################################
# Recording completed. Transcription:  Trial
# ###################################################################################################################
# Recording completed. Transcription:  .
# ###################################################################################################################
# Recording completed. Transcription:  Trial
# ###################################################################################################################
# Recording completed. Transcription:  .
# ###################################################################################################################
# Recording completed. Transcription:  Trial
# ###################################################################################################################
# Recording completed. Transcription:  .
# ###################################################################################################################
# Recording completed. Transcription:  Trial
# ###################################################################################################################
# Recording completed. Transcription:  .
# ###################################################################################################################
# Recording completed. Transcription:  .
# ###################################################################################################################
# Recording completed. Transcription:  Trial
# ###################################################################################################################
# Recording completed. Transcription:  Trial
# ###################################################################################################################
# Recording completed. Transcription:  .
# ###################################################################################################################
# Recording completed. Transcription:  .
# ###################################################################################################################
# Recording completed. Transcription:  Trial
# ###################################################################################################################
# Recording completed. Transcription:  .
# ###################################################################################################################
# Recording completed. Transcription:  Trial
# ###################################################################################################################
# Recording completed. Transcription:  Trial
# ###################################################################################################################
# Recording completed. Transcription:  .
# ###################################################################################################################
# Recording completed. Transcription:  Thank you.
# ###################################################################################################################
# Recording completed. Transcription:  Hello?
# ###################################################################################################################
# Recording completed. Transcription:  Trial.
# ###################################################################################################################
# Recording completed. Transcription:  you
# ###################################################################################################################
# Recording completed. Transcription:  .
# ###################################################################################################################
# Recording completed. Transcription:  Trial
# ###################################################################################################################
# Recording completed. Transcription:  I'm gonna start working
# ###################################################################################################################
# Recording completed. Transcription:  down the back, coming down pit road this time to check the speed, also going to be one to go at the line.
# ###################################################################################################################
# Recording completed. Transcription:  Trial
# ###################################################################################################################
# Recording completed. Transcription:  .
# ###################################################################################################################
# Recording completed. Transcription:  Trial
# ###################################################################################################################
# Recording completed. Transcription:  .
# ###################################################################################################################
# Recording completed. Transcription:  Trial
# ###################################################################################################################
# Recording completed. Transcription:  Trial
# ###################################################################################################################
# Recording completed. Transcription:  Trial
# ###################################################################################################################
# Recording completed. Transcription:  .
# ###################################################################################################################
# Recording completed. Transcription:  Trial
# ###################################################################################################################
# Recording completed. Transcription:  Trial
# ###################################################################################################################
# Recording completed. Transcription:  Gonna be second gear 38.26 to Red.
# ###################################################################################################################
# Recording completed. Transcription:  Trial
# ###################################################################################################################
# Recording completed. Transcription:  Two red, off Bay Road now.
# ###################################################################################################################
# Recording completed. Transcription:  .
# ###################################################################################################################
# Recording completed. Transcription:  .
# ###################################################################################################################
# Recording completed. Transcription:  Trial.
# ###################################################################################################################
# Recording completed. Transcription:  one.
# ###################################################################################################################
# Recording completed. Transcription:  One to go here.
# ###################################################################################################################
# Recording completed. Transcription:  Doubling back up, going to lap 80, switches in three, four...
# ###################################################################################################################
# Recording completed. Transcription:  Appreciate all the hard work.
# ###################################################################################################################
# Recording completed. Transcription:  on yesterday fixing this thing so appreciate it obviously got a pretty good car so try to keep it
# ###################################################################################################################
# Recording completed. Transcription:  It would be pretty cool to get Rusty his first wing. So no better place to do it.
# ###################################################################################################################
# Recording completed. Transcription:  Let me know what I can do better. Just execute all day long. We'll be there at the end.
# ###################################################################################################################
# Recording completed. Transcription:  Everything off pit road looks really really good there, so let's make sure we maintain that all day long.
# ###################################################################################################################
# Recording completed. Transcription:  Let's make sure we stay on top of our adjustments, stay on top of the track. As we said earlier, this should be the time.
# ###################################################################################################################
# Recording completed. Transcription:  So let's keep that in mind as we're talking about what we mean.
# ###################################################################################################################
# Recording completed. Transcription:  Good one.
# ###################################################################################################################
# Recording completed. Transcription:  49, 79, everything was really good there.
# ###################################################################################################################
# Recording completed. Transcription:  Speak focused. Have a good day.
# ###################################################################################################################
# Recording completed. Transcription:  Trial.
# ###################################################################################################################
# Recording completed. Transcription:  Okay, double.
# ###################################################################################################################
# Recording completed. Transcription:  A star is
# ###################################################################################################################
# Recording completed. Transcription:  Stay ready. 10-1. Trial.
# ###################################################################################################################
# Recording completed. Transcription:  4, 3, 2, 1, stay ready. Green, green, green.
# ###################################################################################################################
# Recording completed. Transcription:  Killing.
# ###################################################################################################################
# Recording completed. Transcription:  I'm coming back to you. By one to three, watch.
# ###################################################################################################################
# Recording completed. Transcription:  Top has momentum, 11 is going to be by half here laying now still at your quarter with the 9.
# ###################################################################################################################
# Recording completed. Transcription:  Well...
# ###################################################################################################################
# Recording completed. Transcription:  All clear. All clear by half of an inch.
# ###################################################################################################################
# Recording completed. Transcription:  by two to the 17th in the wall.
# ###################################################################################################################
# Recording completed. Transcription:  3, bottom of 3, 1 outside to the 9, 1 outside, wind up top.
# ###################################################################################################################
# Recording completed. Transcription:  12
# ###################################################################################################################
# Recording completed. Transcription:  Outside 17, even 9 now, might have to see if I can...
# ###################################################################################################################
# Recording completed. Transcription:  Go by half to two by two, even nine at your door.
# ###################################################################################################################
# Recording completed. Transcription:  Coming back to you even by half. It'll be the middle one exit, middle of three, middle of three, middle of three.
# ###################################################################################################################
# Recording completed. Transcription:  Shane!
# ###################################################################################################################
# Recording completed. Transcription:  Outside, outside. 48 flicking, bottom in the middle, clear up. One inside now.
# ###################################################################################################################
# Recording completed. Transcription:  Drive.
# ###################################################################################################################
# Recording completed. Transcription:  to the three two by two behind.
# ###################################################################################################################
# Recording completed. Transcription:  Be patient here.
# ###################################################################################################################
# Recording completed. Transcription:  Thank you.
# ###################################################################################################################
# Recording completed. Transcription:  I have to do by you trial
# ###################################################################################################################
# Recording completed. Transcription:  Trial?
# ###################################################################################################################
# Recording completed. Transcription:  Trial
# ###################################################################################################################
# Recording completed. Transcription:  I'm gonna bleed over, I can't tell if it's one or two.
# ###################################################################################################################
# Recording completed. Transcription:  Nothing. I've not heard a thing. So, I'm half on the wall outside, outside.
# ###################################################################################################################
# Recording completed. Transcription:  out there.
# ###################################################################################################################
# Recording completed. Transcription:  Come on.
# ###################################################################################################################
# Recording completed. Transcription:  We're lifting away earlier and we're going back up here. Going to be top of three.
# ###################################################################################################################
# Recording completed. Transcription:  Trial.
# ###################################################################################################################
# Recording completed. Transcription:  Done!
# ###################################################################################################################
# Recording completed. Transcription:  the bottom by half of a bottom.
# ###################################################################################################################
# Recording completed. Transcription:  My quarter now by the inside, inside, still inside.
# ###################################################################################################################
# Recording completed. Transcription:  22 by one to the three
# ###################################################################################################################
# Recording completed. Transcription:  Drive.
# ###################################################################################################################
# Recording completed. Transcription:  Have to change to our other channel too at some point.
# ###################################################################################################################
# Recording completed. Transcription:  change radios this one works.
# ###################################################################################################################
# Recording completed. Transcription:  Flight 2, second lane now.
# ###################################################################################################################
# Recording completed. Transcription:  Trial.
# ###################################################################################################################
# Recording completed. Transcription:  Yeah
# ###################################################################################################################
# Recording completed. Transcription:  Dreaming most.
# ###################################################################################################################
# Recording completed. Transcription:  One half quarter on the line.
# ###################################################################################################################
# Recording completed. Transcription:  My quarter half a lane lower. Trial.
# ###################################################################################################################
# Recording completed. Transcription:  Over half a lane lower.
# ###################################################################################################################
# Recording completed. Transcription:  I won. Trial?
# ###################################################################################################################
# Recording completed. Transcription:  Jamming!
# ###################################################################################################################
# Recording completed. Transcription:  Born on exit. Trial.
# ###################################################################################################################
# Recording completed. Transcription:  Really high. 10-4, we see it here. Lab 7, man.
# ###################################################################################################################
# Recording completed. Transcription:  Cool.
# ###################################################################################################################
# Recording completed. Transcription:  Okay.
# ###################################################################################################################
# Recording completed. Transcription:  Try it.
# ###################################################################################################################
# Recording completed. Transcription:  A half a side down at the bottom, my three to the three year...
# ###################################################################################################################
# Recording completed. Transcription:  Still even, you have the momentum here at your door.
# ###################################################################################################################
# Recording completed. Transcription:  All clear.
# ###################################################################################################################
# Recording completed. Transcription:  Yeah, could air one and two could still be a touch more patient here.
# ###################################################################################################################
# Recording completed. Transcription:  Trial.
# ###################################################################################################################
# Recording completed. Transcription:  .
# ###################################################################################################################
# Recording completed. Transcription:  Trial.
# ###################################################################################################################
# Recording completed. Transcription:  .
# ###################################################################################################################
# Recording completed. Transcription:  Trial
# ###################################################################################################################
# Recording completed. Transcription:  Trial
# ###################################################################################################################
# Recording completed. Transcription:  .
# ###################################################################################################################
# Recording completed. Transcription:  I'll go by about six or seven to the three.
# ###################################################################################################################
# Recording completed. Transcription:  you
# ###################################################################################################################
# Recording completed. Transcription:  Hello
# ###################################################################################################################
# Recording completed. Transcription:  Bye.
# ...
# Recording completed. Transcription:  Trial
# ###################################################################################################################
# Recording completed. Transcription:  .
# ###################################################################################################################
# Recording completed. Transcription:  Trial
# ###################################################################################################################
# Recording completed. Transcription:  you
# ###################################################################################################################
# Recording completed. Transcription:  Try on.
# ###################################################################################################################
# Recording completed. Transcription:  34 does have some damage from a wreck earlier.
# ###################################################################################################################
# Recording completed. Transcription:  These cars are off, say, trial. And away.
# ###################################################################################################################
# Recording completed. Transcription:  Go ahead, Randy.
# ###################################################################################################################
# Recording completed. Transcription:  All rolling, all rolling.
# ###################################################################################################################
# Recording completed. Transcription:  Drive.
# ###################################################################################################################
# Recording completed. Transcription:  47 still out there outside lined up lined up still
# ###################################################################################################################
# Recording completed. Transcription:  Come!
# ###################################################################################################################
# Recording completed. Transcription:  trial
# ###################################################################################################################
# Recording completed. Transcription:  Still one inside. In the middle. In the middle. In the middle.
# ###################################################################################################################
# Recording completed. Transcription:  flag
# ###################################################################################################################
# Recording completed. Transcription:  Bye.
# ###################################################################################################################
# Recording completed. Transcription:  Go outside, go outside, bottom at three, bottom at three in the middle.
# ###################################################################################################################
# Recording completed. Transcription:  Try.
# ###################################################################################################################
# Recording completed. Transcription:  outside. Still outside one.
# ###################################################################################################################
# Recording completed. Transcription:  outside 54, outside, outside, outside bumper.
# ###################################################################################################################
# Recording completed. Transcription:  It's alright.
# ###################################################################################################################
# Recording completed. Transcription:  .
# ###################################################################################################################
# Recording completed. Transcription:  We've paid it for Tony first.
# ###################################################################################################################
# Recording completed. Transcription:  21st. So I don't know. Definitely not a, uh, not today's
# ###################################################################################################################
# Recording completed. Transcription:  So, got a lot to look at, trying to understand.
# ###################################################################################################################
# Recording completed. Transcription:  I'd probably rather be on offense there.
# ###################################################################################################################
# Recording completed. Transcription:  It all ranks the right call there.
# ###################################################################################################################
# Recording completed. Transcription:  Super circumstantial, but...
# ###################################################################################################################
# Recording completed. Transcription:  Trial
# ###################################################################################################################
# Recording completed. Transcription:  .
# ###################################################################################################################
# Recording completed. Transcription:  .
# ###################################################################################################################
# Recording completed. Transcription:  Trial
# ###################################################################################################################
# Recording completed. Transcription:  Try it.
# ###################################################################################################################
# Recording completed. Transcription:  you
# ###################################################################################################################
# Recording completed. Transcription:  Trial
# ###################################################################################################################
# Recording completed. Transcription:  .
# ###################################################################################################################
# Recording completed. Transcription:  Trial
# ###################################################################################################################
# Recording completed. Transcription:  .
# ###################################################################################################################
# Recording completed. Transcription:  Trial
# ###################################################################################################################
# Recording completed. Transcription:  .
# ###################################################################################################################
# Recording completed. Transcription:  .
# ###################################################################################################################
# Recording completed. Transcription:  Trial
# ###################################################################################################################
# Recording completed. Transcription:  Trial
# ###################################################################################################################
# Recording completed. Transcription:  Trial
# ###################################################################################################################
# Recording completed. Transcription:  .
# ###################################################################################################################
# Recording completed. Transcription:  Trial
# ###################################################################################################################
# Recording completed. Transcription:  Trial
# ###################################################################################################################
# Recording completed. Transcription:  .
# ###################################################################################################################
# Recording completed. Transcription:  Trial
# ###################################################################################################################
# Recording completed. Transcription:  .
# ###################################################################################################################
# Recording completed. Transcription:  Trial
# ###################################################################################################################
# Recording completed. Transcription:  Trial
# ###################################################################################################################
# Recording completed. Transcription:  Trial
# ###################################################################################################################
# Recording completed. Transcription:  .
# ###################################################################################################################
# Recording completed. Transcription:  Trial
# ###################################################################################################################
# Recording completed. Transcription:  .
# ###################################################################################################################
# Recording completed. Transcription:  Trial
# ###################################################################################################################
# Recording completed. Transcription:  .
# ###################################################################################################################
# Recording completed. Transcription:  .
# ###################################################################################################################
# Recording completed. Transcription:  Trial
# ###################################################################################################################
# Recording completed. Transcription:  Trial
# ###################################################################################################################
# Recording completed. Transcription:  .
# ###################################################################################################################
# Recording completed. Transcription:  Trial
# ###################################################################################################################
# Recording completed. Transcription:  Trial
# ###################################################################################################################
# Recording completed. Transcription:  .
# ###################################################################################################################
# Recording completed. Transcription:  Trial
# ###################################################################################################################
# Recording completed. Transcription:  .
# ###################################################################################################################
# Recording completed. Transcription:  Trial
# ###################################################################################################################
# Recording completed. Transcription:  .
# ###################################################################################################################
# Recording completed. Transcription:  Trial
# ###################################################################################################################
# Recording completed. Transcription:  .
# ###################################################################################################################
# Recording completed. Transcription:  While
# ###################################################################################################################
# Recording completed. Transcription:  .
# ###################################################################################################################
# Recording completed. Transcription:  Trial
# ###################################################################################################################
# Recording completed. Transcription:  .
# ###################################################################################################################
# Recording completed. Transcription:  Trial
# ###################################################################################################################
# Recording completed. Transcription:  .
# ###################################################################################################################
# Recording completed. Transcription:  Trial
# ###################################################################################################################
# Recording completed. Transcription:  Trial
# ###################################################################################################################
# Recording completed. Transcription:  .
# ###################################################################################################################
# Recording completed. Transcription:  .
# ###################################################################################################################
# Recording completed. Transcription:  Trial
# ###################################################################################################################
# Recording completed. Transcription:  .
# ###################################################################################################################
# Recording completed. Transcription:  Trial
# ###################################################################################################################
# Recording completed. Transcription:  .
# ###################################################################################################################
# Recording completed. Transcription:  Trial
# ###################################################################################################################
# Recording completed. Transcription:  .
# ###################################################################################################################
# Recording completed. Transcription:  Well?
# ###################################################################################################################
# Recording completed. Transcription:  Trial
# ###################################################################################################################
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 3
#       1 while True:
#       2     #print("Starting a new 10-second recording...")
# ----> 3     transcription = record_audio(5, model=model, processor=processor)
#       4     print("Recording completed. Transcription:", transcription)
#       5     print("###################################################################################################################")
#
# Cell In[1], line 49, in record_audio(duration, model, processor)
#      47 # Start the stream
#      48 with sd.InputStream(callback=audio_callback, samplerate=sampling_rate, channels=channels):
# ---> 49     sd.sleep(duration * 1000)  # Sleep for the duration of the recording
#      52 audio_array = np.concatenate(audio_data)
#      53 audio_array = audio_array.squeeze()
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\sounddevice.py:707, in sleep(msec)
#     700 def sleep(msec):
#     701     """Put the caller to sleep for at least *msec* milliseconds.
#     702
#     703     The function may sleep longer than requested so don't rely on this
#     704     for accurate musical timing.
#     705
#     706     """
# --> 707     _lib.Pa_Sleep(msec)
#
# KeyboardInterrupt:
