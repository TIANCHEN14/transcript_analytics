# %%
import json
import matplotlib.pyplot as plt
import pandas as pd
from tkinter import Tk
from tkinter.filedialog import askopenfilename, askdirectory
import os
from pathlib import Path

Tk().withdraw()
# Out:
# ''

# %%
# create main list to store all the information
# this line is independed from the append function so it will not clear it before the 
main_list = []

# %%
# file directory of all the file
file_dir = askdirectory()


for root, _ , files in os.walk(file_dir):
    for file in files:
        # join the file path
        file_path = os.path.join(file_dir , file)
        
        # refresh templist
        temp_list = []
        
        # load json file
        with open (file_path , "r") as f:
            temp_list = json.load(f)
            
    
        main_list = main_list + temp_list
        
        
print(len(main_list))
# Out:
# 8793

# %%
main_df = pd.DataFrame()

for index, content in enumerate(main_list):
    content_df = pd.DataFrame([content])
    
    main_df = pd.concat([main_df , content_df])
    
print(main_df.columns)
# Out:
# Index(['instruction', 'input', 'clasiifer', 'output'], dtype='object')

# %%
main_df['clasiifer'].value_counts()
# Out:
# clasiifer
# General Spotting      7978
# Vehicle handling       219
# Vehicle Status         172
# Pit Strategy           161
# Spotting Racecraft     154
# Track Info              80
# Race Start              29
# Name: count, dtype: int64

# %%
counts = main_df['clasiifer'].value_counts()
print(type(counts))
# Out:
# <class 'pandas.core.series.Series'>

# %%
plt.pie(counts, labels = counts.index , autopct='%1.1f%%' , pctdistance=1.7, labeldistance=2)
plt.title("Percentage for classifer")
plt.show()

# %%
# export Raw merger files json
with open ("05072024_merge.json" , "w") as f:
    json.dump(main_list , f, indent = 3)

# %%
# export RAW excel file json
main_df.to_excel("05072024_merge.xlsx")
