# %%
import os
import torch
from transformers import AutoModelForCausalLM, AutoTokenizer, pipeline, AutoConfig, BitsAndBytesConfig, GenerationConfig, TrainingArguments
from peft import LoraConfig, PeftModel
from datasets import Dataset, load_dataset
from trl import SFTTrainer
# Out:
# /usr/lib/python3/dist-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.17.3 and <1.25.0 is required for this version of SciPy (detected version 1.25.2
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
# import dataset from the hugging face hub from my own account
dataset = load_dataset('TC14/050724_raw_llama3_instruct')

# %%
# model name
model_name = 'meta-llama/Meta-Llama-3-8B-Instruct'

# tokenizer 
tokenizer = AutoTokenizer.from_pretrained(model_name, use_fast = True)

# add special token padding for that
tokenizer.add_special_tokens({"pad_token" : "<pad>"})
tokenizer.padding_side = 'left'
# Out:
# /home/ubuntu/.local/lib/python3.10/site-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.

# %%
# define compute module
compute_dtype = getattr(torch, 'float16')

# Quantization parameter
bnb_config = BitsAndBytesConfig(
    load_in_4bit = True,
    bnb_4bit_quant_type = 'nf4',
    bnb_4bit_compute_dtype = compute_dtype,
    bnb_4bit_use_double_quant = True,
    
)

# load in the base model
model = AutoModelForCausalLM.from_pretrained(
    model_name,
    quantization_config = bnb_config,
    device_map = "auto"
)

# uniform the input text length
model.resize_token_embeddings(len(tokenizer))
# Configure the pad token in the model
model.config.pad_token_id = tokenizer.pad_token_id
tokenizer.padding_side = 'right'
model.config.use_cache = False

#model = prepare_model_for_kbit_training(model)

# configure lora 
peft_config = LoraConfig(
    lora_alpha = 256,
    lora_dropout = 0.1,
    r = 256,
    bias = 'none',
    task_type = 'CAUSAL_LM',
    target_modules = ['q_proj' , 'v_proj']
)
# Out:
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]

# %%
training_arg = TrainingArguments(
    output_dir = './results/run_6',
    #evaluation_strategy = "steps",
    #do_eval = False,
    per_device_train_batch_size = 8,
    gradient_accumulation_steps = 1,
    #per_device_eval_batch_size = 4,
    log_level = "debug",
    optim = 'paged_adamw_32bit',
    save_steps = 200,
    logging_steps = 10,
    learning_rate = 1e-4,
    #eval_steps = 5,
    fp16 = True,
    num_train_epochs = 3,
    max_grad_norm = 0.3,
    #max_steps = 10,
    warmup_ratio = 0.03,
    lr_scheduler_type = 'constant',
    report_to = "tensorboard"
)

# %%
trainer = SFTTrainer(
        model=model,
        train_dataset=dataset['train'],
        #eval_dataset=dataset['test'],
        peft_config=peft_config,
        dataset_text_field="text",
        max_seq_length=512,
        tokenizer=tokenizer,
        args=training_arg,
)

trainer.train()
# Out:
# Using auto half precision backend
# Currently training with a batch size of: 8
# ***** Running training *****
#   Num examples = 8,793
#   Num Epochs = 3
#   Instantaneous batch size per device = 8
#   Total train batch size (w. parallel, distributed & accumulation) = 8
#   Gradient Accumulation steps = 1
#   Total optimization steps = 3,300
#   Number of trainable parameters = 109,051,904
#     <div>
#
#       <progress value='3300' max='3300' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [3300/3300 23:04, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>10</td>
#       <td>3.799000</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>1.393800</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>1.284800</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>1.193700</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>1.126100</td>
#     </tr>
#     <tr>
#       <td>60</td>
#       <td>1.049800</td>
#     </tr>
#     <tr>
#       <td>70</td>
#       <td>0.962100</td>
#     </tr>
#     <tr>
#       <td>80</td>
#       <td>0.821300</td>
#     </tr>
#     <tr>
#       <td>90</td>
#       <td>0.821400</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>0.810100</td>
#     </tr>
#     <tr>
#       <td>110</td>
#       <td>0.751700</td>
#     </tr>
#     <tr>
#       <td>120</td>
#       <td>0.758700</td>
#     </tr>
#     <tr>
#       <td>130</td>
#       <td>0.716600</td>
#     </tr>
#     <tr>
#       <td>140</td>
#       <td>0.792600</td>
#     </tr>
#     <tr>
#       <td>150</td>
#       <td>0.792900</td>
#     </tr>
#     <tr>
#       <td>160</td>
#       <td>0.760400</td>
#     </tr>
#     <tr>
#       <td>170</td>
#       <td>0.782500</td>
#     </tr>
#     <tr>
#       <td>180</td>
#       <td>0.742200</td>
#     </tr>
#     <tr>
#       <td>190</td>
#       <td>0.775600</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>0.724200</td>
#     </tr>
#     <tr>
#       <td>210</td>
#       <td>0.741300</td>
#     </tr>
#     <tr>
#       <td>220</td>
#       <td>0.725400</td>
#     </tr>
#     <tr>
#       <td>230</td>
#       <td>0.767700</td>
#     </tr>
#     <tr>
#       <td>240</td>
#       <td>0.698300</td>
#     </tr>
#     <tr>
#       <td>250</td>
#       <td>0.682400</td>
#     </tr>
#     <tr>
#       <td>260</td>
#       <td>0.709900</td>
#     </tr>
#     <tr>
#       <td>270</td>
#       <td>0.806200</td>
#     </tr>
#     <tr>
#       <td>280</td>
#       <td>0.731100</td>
#     </tr>
#     <tr>
#       <td>290</td>
#       <td>0.736000</td>
#     </tr>
#     <tr>
#       <td>300</td>
#       <td>0.728300</td>
#     </tr>
#     <tr>
#       <td>310</td>
#       <td>0.774300</td>
#     </tr>
#     <tr>
#       <td>320</td>
#       <td>0.749000</td>
#     </tr>
#     <tr>
#       <td>330</td>
#       <td>0.793200</td>
#     </tr>
#     <tr>
#       <td>340</td>
#       <td>0.695500</td>
#     </tr>
#     <tr>
#       <td>350</td>
#       <td>0.807600</td>
#     </tr>
#     <tr>
#       <td>360</td>
#       <td>0.713700</td>
#     </tr>
#     <tr>
#       <td>370</td>
#       <td>0.771700</td>
#     </tr>
#     <tr>
#       <td>380</td>
#       <td>0.763700</td>
#     </tr>
#     <tr>
#       <td>390</td>
#       <td>0.702600</td>
#     </tr>
#     <tr>
#       <td>400</td>
#       <td>0.712200</td>
#     </tr>
#     <tr>
#       <td>410</td>
#       <td>0.744100</td>
#     </tr>
#     <tr>
#       <td>420</td>
#       <td>0.680500</td>
#     </tr>
#     <tr>
#       <td>430</td>
#       <td>0.694800</td>
#     </tr>
#     <tr>
#       <td>440</td>
#       <td>0.810100</td>
#     </tr>
#     <tr>
#       <td>450</td>
#       <td>0.734400</td>
#     </tr>
#     <tr>
#       <td>460</td>
#       <td>0.741600</td>
#     </tr>
#     <tr>
#       <td>470</td>
#       <td>0.751600</td>
#     </tr>
#     <tr>
#       <td>480</td>
#       <td>0.768200</td>
#     </tr>
#     <tr>
#       <td>490</td>
#       <td>0.766400</td>
#     </tr>
#     <tr>
#       <td>500</td>
#       <td>0.714400</td>
#     </tr>
#     <tr>
#       <td>510</td>
#       <td>0.714900</td>
#     </tr>
#     <tr>
#       <td>520</td>
#       <td>0.812900</td>
#     </tr>
#     <tr>
#       <td>530</td>
#       <td>0.705400</td>
#     </tr>
#     <tr>
#       <td>540</td>
#       <td>0.796600</td>
#     </tr>
#     <tr>
#       <td>550</td>
#       <td>0.724800</td>
#     </tr>
#     <tr>
#       <td>560</td>
#       <td>0.676300</td>
#     </tr>
#     <tr>
#       <td>570</td>
#       <td>0.695600</td>
#     </tr>
#     <tr>
#       <td>580</td>
#       <td>0.717800</td>
#     </tr>
#     <tr>
#       <td>590</td>
#       <td>0.719100</td>
#     </tr>
#     <tr>
#       <td>600</td>
#       <td>0.730200</td>
#     </tr>
#     <tr>
#       <td>610</td>
#       <td>0.727900</td>
#     </tr>
#     <tr>
#       <td>620</td>
#       <td>0.692200</td>
#     </tr>
#     <tr>
#       <td>630</td>
#       <td>0.682600</td>
#     </tr>
#     <tr>
#       <td>640</td>
#       <td>0.716200</td>
#     </tr>
#     <tr>
#       <td>650</td>
#       <td>0.726500</td>
#     </tr>
#     <tr>
#       <td>660</td>
#       <td>0.692600</td>
#     </tr>
#     <tr>
#       <td>670</td>
#       <td>0.711100</td>
#     </tr>
#     <tr>
#       <td>680</td>
#       <td>0.674400</td>
#     </tr>
#     <tr>
#       <td>690</td>
#       <td>0.732400</td>
#     </tr>
#     <tr>
#       <td>700</td>
#       <td>0.660700</td>
#     </tr>
#     <tr>
#       <td>710</td>
#       <td>0.693800</td>
#     </tr>
#     <tr>
#       <td>720</td>
#       <td>0.726800</td>
#     </tr>
#     <tr>
#       <td>730</td>
#       <td>0.748300</td>
#     </tr>
#     <tr>
#       <td>740</td>
#       <td>0.775300</td>
#     </tr>
#     <tr>
#       <td>750</td>
#       <td>0.718900</td>
#     </tr>
#     <tr>
#       <td>760</td>
#       <td>0.779900</td>
#     </tr>
#     <tr>
#       <td>770</td>
#       <td>0.669200</td>
#     </tr>
#     <tr>
#       <td>780</td>
#       <td>0.659900</td>
#     </tr>
#     <tr>
#       <td>790</td>
#       <td>0.653500</td>
#     </tr>
#     <tr>
#       <td>800</td>
#       <td>0.704200</td>
#     </tr>
#     <tr>
#       <td>810</td>
#       <td>0.724000</td>
#     </tr>
#     <tr>
#       <td>820</td>
#       <td>0.690600</td>
#     </tr>
#     <tr>
#       <td>830</td>
#       <td>0.716700</td>
#     </tr>
#     <tr>
#       <td>840</td>
#       <td>0.722200</td>
#     </tr>
#     <tr>
#       <td>850</td>
#       <td>0.797300</td>
#     </tr>
#     <tr>
#       <td>860</td>
#       <td>0.684100</td>
#     </tr>
#     <tr>
#       <td>870</td>
#       <td>0.799700</td>
#     </tr>
#     <tr>
#       <td>880</td>
#       <td>0.744300</td>
#     </tr>
#     <tr>
#       <td>890</td>
#       <td>0.651700</td>
#     </tr>
#     <tr>
#       <td>900</td>
#       <td>0.736600</td>
#     </tr>
#     <tr>
#       <td>910</td>
#       <td>0.735100</td>
#     </tr>
#     <tr>
#       <td>920</td>
#       <td>0.677500</td>
#     </tr>
#     <tr>
#       <td>930</td>
#       <td>0.729000</td>
#     </tr>
#     <tr>
#       <td>940</td>
#       <td>0.758100</td>
#     </tr>
#     <tr>
#       <td>950</td>
#       <td>0.635300</td>
#     </tr>
#     <tr>
#       <td>960</td>
#       <td>0.663500</td>
#     </tr>
#     <tr>
#       <td>970</td>
#       <td>0.695400</td>
#     </tr>
#     <tr>
#       <td>980</td>
#       <td>0.736000</td>
#     </tr>
#     <tr>
#       <td>990</td>
#       <td>0.714600</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>0.730800</td>
#     </tr>
#     <tr>
#       <td>1010</td>
#       <td>0.663700</td>
#     </tr>
#     <tr>
#       <td>1020</td>
#       <td>0.671200</td>
#     </tr>
#     <tr>
#       <td>1030</td>
#       <td>0.667100</td>
#     </tr>
#     <tr>
#       <td>1040</td>
#       <td>0.705200</td>
#     </tr>
#     <tr>
#       <td>1050</td>
#       <td>0.702500</td>
#     </tr>
#     <tr>
#       <td>1060</td>
#       <td>0.660600</td>
#     </tr>
#     <tr>
#       <td>1070</td>
#       <td>0.633400</td>
#     </tr>
#     <tr>
#       <td>1080</td>
#       <td>0.713900</td>
#     </tr>
#     <tr>
#       <td>1090</td>
#       <td>0.725100</td>
#     </tr>
#     <tr>
#       <td>1100</td>
#       <td>0.680600</td>
#     </tr>
#     <tr>
#       <td>1110</td>
#       <td>0.606500</td>
#     </tr>
#     <tr>
#       <td>1120</td>
#       <td>0.606100</td>
#     </tr>
#     <tr>
#       <td>1130</td>
#       <td>0.689500</td>
#     </tr>
#     <tr>
#       <td>1140</td>
#       <td>0.593300</td>
#     </tr>
#     <tr>
#       <td>1150</td>
#       <td>0.623600</td>
#     </tr>
#     <tr>
#       <td>1160</td>
#       <td>0.689800</td>
#     </tr>
#     <tr>
#       <td>1170</td>
#       <td>0.669100</td>
#     </tr>
#     <tr>
#       <td>1180</td>
#       <td>0.677600</td>
#     </tr>
#     <tr>
#       <td>1190</td>
#       <td>0.690900</td>
#     </tr>
#     <tr>
#       <td>1200</td>
#       <td>0.673600</td>
#     </tr>
#     <tr>
#       <td>1210</td>
#       <td>0.618000</td>
#     </tr>
#     <tr>
#       <td>1220</td>
#       <td>0.690800</td>
#     </tr>
#     <tr>
#       <td>1230</td>
#       <td>0.655900</td>
#     </tr>
#     <tr>
#       <td>124
# Saving model checkpoint to ./results/run_6/checkpoint-200
# /home/ubuntu/.local/lib/python3.10/site-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# loading configuration file config.json from cache at /home/ubuntu/.cache/huggingface/hub/models--meta-llama--Meta-Llama-3-8B-Instruct/snapshots/e5e23bbe8e749ef0efcf16cad411a7d23bd23298/config.json
# Model config LlamaConfig {
#   "architectures": [
#     "LlamaForCausalLM"
#   ],
#   "attention_bias": false,
#   "attention_dropout": 0.0,
#   "bos_token_id": 128000,
#   "eos_token_id": 128001,
#   "hidden_act": "silu",
#   "hidden_size": 4096,
#   "initializer_range": 0.02,
#   "intermediate_size": 14336,
#   "max_position_embeddings": 8192,
#   "model_type": "llama",
#   "num_attention_heads": 32,
#   "num_hidden_layers": 32,
#   "num_key_value_heads": 8,
#   "pretraining_tp": 1,
#   "rms_norm_eps": 1e-05,
#   "rope_scaling": null,
#   "rope_theta": 500000.0,
#   "tie_word_embeddings": false,
#   "torch_dtype": "bfloat16",
#   "transformers_version": "4.40.2",
#   "use_cache": true,
#   "vocab_size": 128256
# }
#
# /home/ubuntu/.local/lib/python3.10/site-packages/peft/utils/save_and_load.py:168: UserWarning: Setting `save_embedding_layers` to `True` as the embedding layer has been resized during finetuning.
#   warnings.warn(
# tokenizer config file saved in ./results/run_6/checkpoint-200/tokenizer_config.json
# Special tokens file saved in ./results/run_6/checkpoint-200/special_tokens_map.json
# Saving model checkpoint to ./results/run_6/checkpoint-400
# /home/ubuntu/.local/lib/python3.10/site-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# loading configuration file config.json from cache at /home/ubuntu/.cache/huggingface/hub/models--meta-llama--Meta-Llama-3-8B-Instruct/snapshots/e5e23bbe8e749ef0efcf16cad411a7d23bd23298/config.json
# Model config LlamaConfig {
#   "architectures": [
#     "LlamaForCausalLM"
#   ],
#   "attention_bias": false,
#   "attention_dropout": 0.0,
#   "bos_token_id": 128000,
#   "eos_token_id": 128001,
#   "hidden_act": "silu",
#   "hidden_size": 4096,
#   "initializer_range": 0.02,
#   "intermediate_size": 14336,
#   "max_position_embeddings": 8192,
#   "model_type": "llama",
#   "num_attention_heads": 32,
#   "num_hidden_layers": 32,
#   "num_key_value_heads": 8,
#   "pretraining_tp": 1,
#   "rms_norm_eps": 1e-05,
#   "rope_scaling": null,
#   "rope_theta": 500000.0,
#   "tie_word_embeddings": false,
#   "torch_dtype": "bfloat16",
#   "transformers_version": "4.40.2",
#   "use_cache": true,
#   "vocab_size": 128256
# }
#
# /home/ubuntu/.local/lib/python3.10/site-packages/peft/utils/save_and_load.py:168: UserWarning: Setting `save_embedding_layers` to `True` as the embedding layer has been resized during finetuning.
#   warnings.warn(
# tokenizer config file saved in ./results/run_6/checkpoint-400/tokenizer_config.json
# Special tokens file saved in ./results/run_6/checkpoint-400/special_tokens_map.json
# Saving model checkpoint to ./results/run_6/checkpoint-600
# /home/ubuntu/.local/lib/python3.10/site-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# loading configuration file config.json from cache at /home/ubuntu/.cache/huggingface/hub/models--meta-llama--Meta-Llama-3-8B-Instruct/snapshots/e5e23bbe8e749ef0efcf16cad411a7d23bd23298/config.json
# Model config LlamaConfig {
#   "architectures": [
#     "LlamaForCausalLM"
#   ],
#   "attention_bias": false,
#   "attention_dropout": 0.0,
#   "bos_token_id": 128000,
#   "eos_token_id": 128001,
#   "hidden_act": "silu",
#   "hidden_size": 4096,
#   "initializer_range": 0.02,
#   "intermediate_size": 14336,
#   "max_position_embeddings": 8192,
#   "model_type": "llama",
#   "num_attention_heads": 32,
#   "num_hidden_layers": 32,
#   "num_key_value_heads": 8,
#   "pretraining_tp": 1,
#   "rms_norm_eps": 1e-05,
#   "rope_scaling": null,
#   "rope_theta": 500000.0,
#   "tie_word_embeddings": false,
#   "torch_dtype": "bfloat16",
#   "transformers_version": "4.40.2",
#   "use_cache": true,
#   "vocab_size": 128256
# }
#
# /home/ubuntu/.local/lib/python3.10/site-packages/peft/utils/save_and_load.py:168: UserWarning: Setting `save_embedding_layers` to `True` as the embedding layer has been resized during finetuning.
#   warnings.warn(
# tokenizer config file saved in ./results/run_6/checkpoint-600/tokenizer_config.json
# Special tokens file saved in ./results/run_6/checkpoint-600/special_tokens_map.json
# Saving model checkpoint to ./results/run_6/checkpoint-800
# /home/ubuntu/.local/lib/python3.10/site-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# loading configuration file config.json from cache at /home/ubuntu/.cache/huggingface/hub/models--meta-llama--Meta-Llama-3-8B-Instruct/snapshots/e5e23bbe8e749ef0efcf16cad411a7d23bd23298/config.json
# Model config LlamaConfig {
#   "architectures": [
#     "LlamaForCausalLM"
#   ],
#   "attention_bias": false,
#   "attention_dropout": 0.0,
#   "bos_token_id": 128000,
#   "eos_token_id": 128001,
#   "hidden_act": "silu",
#   "hidden_size": 4096,
#   "initializer_range": 0.02,
#   "intermediate_size": 14336,
#   "max_position_embeddings": 8192,
#   "model_type": "llama",
#   "num_attention_heads": 32,
#   "num_hidden_layers": 32,
#   "num_key_value_heads": 8,
#   "pretraining_tp": 1,
#   "rms_norm_eps": 1e-05,
#   "rope_scaling": null,
#   "rope_theta": 500000.0,
#   "tie_word_embeddings": false,
#   "torch_dtype": "bfloat16",
#   "transformers_version": "4.40.2",
#   "use_cache": true,
#   "vocab_size": 128256
# }
#
# /home/ubuntu/.local/lib/python3.10/site-packages/peft/utils/save_and_load.py:168: UserWarning: Setting `save_embedding_layers` to `True` as the embedding layer has been resized during finetuning.
#   warnings.warn(
# tokenizer config file saved in ./results/run_6/checkpoint-800/tokenizer_config.json
# Special tokens file saved in ./results/run_6/checkpoint-800/special_tokens_map.json
# Saving model checkpoint to ./results/run_6/checkpoint-1000
# /home/ubuntu/.local/lib/python3.10/site-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# loading configuration file config.json from cache at /home/ubuntu/.cache/huggingface/hub/models--meta-llama--Meta-Llama-3-8B-Instruct/snapshots/e5e23bbe8e749ef0efcf16cad411a7d23bd23298/config.json
# Model config LlamaConfig {
#   "architectures": [
#     "LlamaForCausalLM"
#   ],
#   "attention_bias": false,
#   "attention_dropout": 0.0,
#   "bos_token_id": 128000,
#   "eos_token_id": 128001,
#   "hidden_act": "silu",
#   "hidden_size": 4096,
#   "initializer_range": 0.02,
#   "intermediate_size": 14336,
#   "max_position_embeddings": 8192,
#   "model_type": "llama",
#   "num_attention_heads": 32,
#   "num_hidden_layers": 32,
#   "num_key_value_heads": 8,
#   "pretraining_tp": 1,
#   "rms_norm_eps": 1e-05,
#   "rope_scaling": null,
#   "rope_theta": 500000.0,
#   "tie_word_embeddings": false,
#   "torch_dtype": "bfloat16",
#   "transformers_version": "4.40.2",
#   "use_cache": true,
#   "vocab_size": 128256
# }
#
# /home/ubuntu/.local/lib/python3.10/site-packages/peft/utils/save_and_load.py:168: UserWarning: Setting `save_embedding_layers` to `True` as the embedding layer has been resized during finetuning.
#   warnings.warn(
# tokenizer config file saved in ./results/run_6/checkpoint-1000/tokenizer_config.json
# Special tokens file saved in ./results/run_6/checkpoint-1000/special_tokens_map.json
# Saving model checkpoint to ./results/run_6/checkpoint-1200
# /home/ubuntu/.local/lib/python3.10/site-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# loading configuration file config.json from cache at /home/ubuntu/.cache/huggingface/hub/models--meta-llama--Meta-Llama-3-8B-Instruct/snapshots/e5e23bbe8e749ef0efcf16cad411a7d23bd23298/config.json
# Model config LlamaConfig {
#   "architectures": [
#     "LlamaForCausalLM"
#   ],
#   "attention_bias": false,
#   "attention_dropout": 0.0,
#   "bos_token_id": 128000,
#   "eos_token_id": 128001,
#   "hidden_act": "silu",
#   "hidden_size": 4096,
#   "initializer_range": 0.02,
#   "intermediate_size": 14336,
#   "max_position_embeddings": 8192,
#   "model_type": "llama",
#   "num_attention_heads": 32,
#   "num_hidden_layers": 32,
#   "num_key_value_heads": 8,
#   "pretraining_tp": 1,
#   "rms_norm_eps": 1e-05,
#   "rope_scaling": null,
#   "rope_theta": 500000.0,
#   "tie_word_embeddings": false,
#   "torch_dtype": "bfloat16",
#   "transformers_version": "4.40.2",
#   "use_cache": true,
#   "vocab_size": 128256
# }
#
# /home/ubuntu/.local/lib/python3.10/site-packages/peft/utils/save_and_load.py:168: UserWarning: Setting `save_embedding_layers` to `True` as the embedding layer has been resized during finetuning.
#   warnings.warn(
# tokenizer config file saved in ./results/run_6/checkpoint-1200/tokenizer_config.json
# Special tokens file saved in ./results/run_6/checkpoint-1200/special_tokens_map.json
# Saving model checkpoint to ./results/run_6/checkpoint-1400
# /home/ubuntu/.local/lib/python3.10/site-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# loading configuration file config.json from cache at /home/ubuntu/.cache/huggingface/hub/models--meta-llama--Meta-Llama-3-8B-Instruct/snapshots/e5e23bbe8e749ef0efcf16cad411a7d23bd23298/config.json
# Model config LlamaConfig {
#   "architectures": [
#     "LlamaForCausalLM"
#   ],
#   "attention_bias": false,
#   "attention_dropout": 0.0,
#   "bos_token_id": 128000,
#   "eos_token_id": 128001,
#   "hidden_act": "silu",
#   "hidden_size": 4096,
#   "initializer_range": 0.02,
#   "intermediate_size": 14336,
#   "max_position_embeddings": 8192,
#   "model_type": "llama",
#   "num_attention_heads": 32,
#   "num_hidden_layers": 32,
#   "num_key_value_heads": 8,
#   "pretraining_tp": 1,
#   "rms_norm_eps": 1e-05,
#   "rope_scaling": null,
#   "rope_theta": 500000.0,
#   "tie_word_embeddings": false,
#   "torch_dtype": "bfloat16",
#   "transformers_version": "4.40.2",
#   "use_cache": true,
#   "vocab_size": 128256
# }
#
# /home/ubuntu/.local/lib/python3.10/site-packages/peft/utils/save_and_load.py:168: UserWarning: Setting `save_embedding_layers` to `True` as the embedding layer has been resized during finetuning.
#   warnings.warn(
# tokenizer config file saved in ./results/run_6/checkpoint-1400/tokenizer_config.json
# Special tokens file saved in ./results/run_6/checkpoint-1400/special_tokens_map.json
# Saving model checkpoint to ./results/run_6/checkpoint-1600
# /home/ubuntu/.local/lib/python3.10/site-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# loading configuration file config.json from cache at /home/ubuntu/.cache/huggingface/hub/models--meta-llama--Meta-Llama-3-8B-Instruct/snapshots/e5e23bbe8e749ef0efcf16cad411a7d23bd23298/config.json
# Model config LlamaConfig {
#   "architectures": [
#     "LlamaForCausalLM"
#   ],
#   "attention_bias": false,
#   "attention_dropout": 0.0,
#   "bos_token_id": 128000,
#   "eos_token_id": 128001,
#   "hidden_act": "silu",
#   "hidden_size": 4096,
#   "initializer_range": 0.02,
#   "intermediate_size": 14336,
#   "max_position_embeddings": 8192,
#   "model_type": "llama",
#   "num_attention_heads": 32,
#   "num_hidden_layers": 32,
#   "num_key_value_heads": 8,
#   "pretraining_tp": 1,
#   "rms_norm_eps": 1e-05,
#   "rope_scaling": null,
#   "rope_theta": 500000.0,
#   "tie_word_embeddings": false,
#   "torch_dtype": "bfloat16",
#   "transformers_version": "4.40.2",
#   "use_cache": true,
#   "vocab_size": 128256
# }
#
# /home/ubuntu/.local/lib/python3.10/site-packages/peft/utils/save_and_load.py:168: UserWarning: Setting `save_embedding_layers` to `True` as the embedding layer has been resized during finetuning.
#   warnings.warn(
# tokenizer config file saved in ./results/run_6/checkpoint-1600/tokenizer_config.json
# Special tokens file saved in ./results/run_6/checkpoint-1600/special_tokens_map.json
# Saving model checkpoint to ./results/run_6/checkpoint-1800
# /home/ubuntu/.local/lib/python3.10/site-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# loading configuration file config.json from cache at /home/ubuntu/.cache/huggingface/hub/models--meta-llama--Meta-Llama-3-8B-Instruct/snapshots/e5e23bbe8e749ef0efcf16cad411a7d23bd23298/config.json
# Model config LlamaConfig {
#   "architectures": [
#     "LlamaForCausalLM"
#   ],
#   "attention_bias": false,
#   "attention_dropout": 0.0,
#   "bos_token_id": 128000,
#   "eos_token_id": 128001,
#   "hidden_act": "silu",
#   "hidden_size": 4096,
#   "initializer_range": 0.02,
#   "intermediate_size": 14336,
#   "max_position_embeddings": 8192,
#   "model_type": "llama",
#   "num_attention_heads": 32,
#   "num_hidden_layers": 32,
#   "num_key_value_heads": 8,
#   "pretraining_tp": 1,
#   "rms_norm_eps": 1e-05,
#   "rope_scaling": null,
#   "rope_theta": 500000.0,
#   "tie_word_embeddings": false,
#   "torch_dtype": "bfloat16",
#   "transformers_version": "4.40.2",
#   "use_cache": true,
#   "vocab_size": 128256
# }
#
# /home/ubuntu/.local/lib/python3.10/site-packages/peft/utils/save_and_load.py:168: UserWarning: Setting `save_embedding_layers` to `True` as the embedding layer has been resized during finetuning.
#   warnings.warn(
# tokenizer config file saved in ./results/run_6/checkpoint-1800/tokenizer_config.json
# Special tokens file saved in ./results/run_6/checkpoint-1800/special_tokens_map.json
# Saving model checkpoint to ./results/run_6/checkpoint-2000
# /home/ubuntu/.local/lib/python3.10/site-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# loading configuration file config.json from cache at /home/ubuntu/.cache/huggingface/hub/models--meta-llama--Meta-Llama-3-8B-Instruct/snapshots/e5e23bbe8e749ef0efcf16cad411a7d23bd23298/config.json
# Model config LlamaConfig {
#   "architectures": [
#     "LlamaForCausalLM"
#   ],
#   "attention_bias": false,
#   "attention_dropout": 0.0,
#   "bos_token_id": 128000,
#   "eos_token_id": 128001,
#   "hidden_act": "silu",
#   "hidden_size": 4096,
#   "initializer_range": 0.02,
#   "intermediate_size": 14336,
#   "max_position_embeddings": 8192,
#   "model_type": "llama",
#   "num_attention_heads": 32,
#   "num_hidden_layers": 32,
#   "num_key_value_heads": 8,
#   "pretraining_tp": 1,
#   "rms_norm_eps": 1e-05,
#   "rope_scaling": null,
#   "rope_theta": 500000.0,
#   "tie_word_embeddings": false,
#   "torch_dtype": "bfloat16",
#   "transformers_version": "4.40.2",
#   "use_cache": true,
#   "vocab_size": 128256
# }
#
# /home/ubuntu/.local/lib/python3.10/site-packages/peft/utils/save_and_load.py:168: UserWarning: Setting `save_embedding_layers` to `True` as the embedding layer has been resized during finetuning.
#   warnings.warn(
# tokenizer config file saved in ./results/run_6/checkpoint-2000/tokenizer_config.json
# Special tokens file saved in ./results/run_6/checkpoint-2000/special_tokens_map.json
# Saving model checkpoint to ./results/run_6/checkpoint-2200
# /home/ubuntu/.local/lib/python3.10/site-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# loading configuration file config.json from cache at /home/ubuntu/.cache/huggingface/hub/models--meta-llama--Meta-Llama-3-8B-Instruct/snapshots/e5e23bbe8e749ef0efcf16cad411a7d23bd23298/config.json
# Model config LlamaConfig {
#   "architectures": [
#     "LlamaForCausalLM"
#   ],
#   "attention_bias": false,
#   "attention_dropout": 0.0,
#   "bos_token_id": 128000,
#   "eos_token_id": 128001,
#   "hidden_act": "silu",
#   "hidden_size": 4096,
#   "initializer_range": 0.02,
#   "intermediate_size": 14336,
#   "max_position_embeddings": 8192,
#   "model_type": "llama",
#   "num_attention_heads": 32,
#   "num_hidden_layers": 32,
#   "num_key_value_heads": 8,
#   "pretraining_tp": 1,
#   "rms_norm_eps": 1e-05,
#   "rope_scaling": null,
#   "rope_theta": 500000.0,
#   "tie_word_embeddings": false,
#   "torch_dtype": "bfloat16",
#   "transformers_version": "4.40.2",
#   "use_cache": true,
#   "vocab_size": 128256
# }
#
# /home/ubuntu/.local/lib/python3.10/site-packages/peft/utils/save_and_load.py:168: UserWarning: Setting `save_embedding_layers` to `True` as the embedding layer has been resized during finetuning.
#   warnings.warn(
# tokenizer config file saved in ./results/run_6/checkpoint-2200/tokenizer_config.json
# Special tokens file saved in ./results/run_6/checkpoint-2200/special_tokens_map.json
# Saving model checkpoint to ./results/run_6/checkpoint-2400
# /home/ubuntu/.local/lib/python3.10/site-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# loading configuration file config.json from cache at /home/ubuntu/.cache/huggingface/hub/models--meta-llama--Meta-Llama-3-8B-Instruct/snapshots/e5e23bbe8e749ef0efcf16cad411a7d23bd23298/config.json
# Model config LlamaConfig {
#   "architectures": [
#     "LlamaForCausalLM"
#   ],
#   "attention_bias": false,
#   "attention_dropout": 0.0,
#   "bos_token_id": 128000,
#   "eos_token_id": 128001,
#   "hidden_act": "silu",
#   "hidden_size": 4096,
#   "initializer_range": 0.02,
#   "intermediate_size": 14336,
#   "max_position_embeddings": 8192,
#   "model_type": "llama",
#   "num_attention_heads": 32,
#   "num_hidden_layers": 32,
#   "num_key_value_heads": 8,
#   "pretraining_tp": 1,
#   "rms_norm_eps": 1e-05,
#   "rope_scaling": null,
#   "rope_theta": 500000.0,
#   "tie_word_embeddings": false,
#   "torch_dtype": "bfloat16",
#   "transformers_version": "4.40.2",
#   "use_cache": true,
#   "vocab_size": 128256
# }
#
# /home/ubuntu/.local/lib/python3.10/site-packages/peft/utils/save_and_load.py:168: UserWarning: Setting `save_embedding_layers` to `True` as the embedding layer has been resized during finetuning.
#   warnings.warn(
# tokenizer config file saved in ./results/run_6/checkpoint-2400/tokenizer_config.json
# Special tokens file saved in ./results/run_6/checkpoint-2400/special_tokens_map.json
# Saving model checkpoint to ./results/run_6/checkpoint-2600
# /home/ubuntu/.local/lib/python3.10/site-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# loading configuration file config.json from cache at /home/ubuntu/.cache/huggingface/hub/models--meta-llama--Meta-Llama-3-8B-Instruct/snapshots/e5e23bbe8e749ef0efcf16cad411a7d23bd23298/config.json
# Model config LlamaConfig {
#   "architectures": [
#     "LlamaForCausalLM"
#   ],
#   "attention_bias": false,
#   "attention_dropout": 0.0,
#   "bos_token_id": 128000,
#   "eos_token_id": 128001,
#   "hidden_act": "silu",
#   "hidden_size": 4096,
#   "initializer_range": 0.02,
#   "intermediate_size": 14336,
#   "max_position_embeddings": 8192,
#   "model_type": "llama",
#   "num_attention_heads": 32,
#   "num_hidden_layers": 32,
#   "num_key_value_heads": 8,
#   "pretraining_tp": 1,
#   "rms_norm_eps": 1e-05,
#   "rope_scaling": null,
#   "rope_theta": 500000.0,
#   "tie_word_embeddings": false,
#   "torch_dtype": "bfloat16",
#   "transformers_version": "4.40.2",
#   "use_cache": true,
#   "vocab_size": 128256
# }
#
# /home/ubuntu/.local/lib/python3.10/site-packages/peft/utils/save_and_load.py:168: UserWarning: Setting `save_embedding_layers` to `True` as the embedding layer has been resized during finetuning.
#   warnings.warn(
# tokenizer config file saved in ./results/run_6/checkpoint-2600/tokenizer_config.json
# Special tokens file saved in ./results/run_6/checkpoint-2600/special_tokens_map.json
# Saving model checkpoint to ./results/run_6/checkpoint-2800
# /home/ubuntu/.local/lib/python3.10/site-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# loading configuration file config.json from cache at /home/ubuntu/.cache/huggingface/hub/models--meta-llama--Meta-Llama-3-8B-Instruct/snapshots/e5e23bbe8e749ef0efcf16cad411a7d23bd23298/config.json
# Model config LlamaConfig {
#   "architectures": [
#     "LlamaForCausalLM"
#   ],
#   "attention_bias": false,
#   "attention_dropout": 0.0,
#   "bos_token_id": 128000,
#   "eos_token_id": 128001,
#   "hidden_act": "silu",
#   "hidden_size": 4096,
#   "initializer_range": 0.02,
#   "intermediate_size": 14336,
#   "max_position_embeddings": 8192,
#   "model_type": "llama",
#   "num_attention_heads": 32,
#   "num_hidden_layers": 32,
#   "num_key_value_heads": 8,
#   "pretraining_tp": 1,
#   "rms_norm_eps": 1e-05,
#   "rope_scaling": null,
#   "rope_theta": 500000.0,
#   "tie_word_embeddings": false,
#   "torch_dtype": "bfloat16",
#   "transformers_version": "4.40.2",
#   "use_cache": true,
#   "vocab_size": 128256
# }
#
# /home/ubuntu/.local/lib/python3.10/site-packages/peft/utils/save_and_load.py:168: UserWarning: Setting `save_embedding_layers` to `True` as the embedding layer has been resized during finetuning.
#   warnings.warn(
# tokenizer config file saved in ./results/run_6/checkpoint-2800/tokenizer_config.json
# Special tokens file saved in ./results/run_6/checkpoint-2800/special_tokens_map.json
# Saving model checkpoint to ./results/run_6/checkpoint-3000
# /home/ubuntu/.local/lib/python3.10/site-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# loading configuration file config.json from cache at /home/ubuntu/.cache/huggingface/hub/models--meta-llama--Meta-Llama-3-8B-Instruct/snapshots/e5e23bbe8e749ef0efcf16cad411a7d23bd23298/config.json
# Model config LlamaConfig {
#   "architectures": [
#     "LlamaForCausalLM"
#   ],
#   "attention_bias": false,
#   "attention_dropout": 0.0,
#   "bos_token_id": 128000,
#   "eos_token_id": 128001,
#   "hidden_act": "silu",
#   "hidden_size": 4096,
#   "initializer_range": 0.02,
#   "intermediate_size": 14336,
#   "max_position_embeddings": 8192,
#   "model_type": "llama",
#   "num_attention_heads": 32,
#   "num_hidden_layers": 32,
#   "num_key_value_heads": 8,
#   "pretraining_tp": 1,
#   "rms_norm_eps": 1e-05,
#   "rope_scaling": null,
#   "rope_theta": 500000.0,
#   "tie_word_embeddings": false,
#   "torch_dtype": "bfloat16",
#   "transformers_version": "4.40.2",
#   "use_cache": true,
#   "vocab_size": 128256
# }
#
# /home/ubuntu/.local/lib/python3.10/site-packages/peft/utils/save_and_load.py:168: UserWarning: Setting `save_embedding_layers` to `True` as the embedding layer has been resized during finetuning.
#   warnings.warn(
# tokenizer config file saved in ./results/run_6/checkpoint-3000/tokenizer_config.json
# Special tokens file saved in ./results/run_6/checkpoint-3000/special_tokens_map.json
# Saving model checkpoint to ./results/run_6/checkpoint-3200
# /home/ubuntu/.local/lib/python3.10/site-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# loading configuration file config.json from cache at /home/ubuntu/.cache/huggingface/hub/models--meta-llama--Meta-Llama-3-8B-Instruct/snapshots/e5e23bbe8e749ef0efcf16cad411a7d23bd23298/config.json
# Model config LlamaConfig {
#   "architectures": [
#     "LlamaForCausalLM"
#   ],
#   "attention_bias": false,
#   "attention_dropout": 0.0,
#   "bos_token_id": 128000,
#   "eos_token_id": 128001,
#   "hidden_act": "silu",
#   "hidden_size": 4096,
#   "initializer_range": 0.02,
#   "intermediate_size": 14336,
#   "max_position_embeddings": 8192,
#   "model_type": "llama",
#   "num_attention_heads": 32,
#   "num_hidden_layers": 32,
#   "num_key_value_heads": 8,
#   "pretraining_tp": 1,
#   "rms_norm_eps": 1e-05,
#   "rope_scaling": null,
#   "rope_theta": 500000.0,
#   "tie_word_embeddings": false,
#   "torch_dtype": "bfloat16",
#   "transformers_version": "4.40.2",
#   "use_cache": true,
#   "vocab_size": 128256
# }
#
# /home/ubuntu/.local/lib/python3.10/site-packages/peft/utils/save_and_load.py:168: UserWarning: Setting `save_embedding_layers` to `True` as the embedding layer has been resized during finetuning.
#   warnings.warn(
# tokenizer config file saved in ./results/run_6/checkpoint-3200/tokenizer_config.json
# Special tokens file saved in ./results/run_6/checkpoint-3200/special_tokens_map.json
#
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
# TrainOutput(global_step=3300, training_loss=0.673738856604605, metrics={'train_runtime': 1386.0718, 'train_samples_per_second': 19.031, 'train_steps_per_second': 2.381, 'total_flos': 6.978629009232691e+16, 'train_loss': 0.673738856604605, 'epoch': 3.0})

# %%
model = PeftModel.from_pretrained(model, "./results/run_2/checkpoint-200")

# %%
messages = [{'role': 'system', 'content': 'You are an radio transcript message transcript assisant, please classifer the following message'},
         {'role': 'user', 'content': 'Overall balance is really good'}]

prompt = tokenizer.apply_chat_template(
    messages,
    return_tensors = "pt"
)

#text_input = tokenizer(prompt , return_tensors = "pt")

#print(text_input)

model.to("cuda")
model_input = prompt.cuda()

generation_output = model.generate(
    model_input,
    max_new_tokens = 20,
    do_sample = True
)

decoded = tokenizer.batch_decode(generation_output)
print(decoded)
# Out:
# ['<s> ### Human : Please classify what kind of comment is this  clear clear clear. ### Assistant :  General Info, Matt,']

# %%
del model

torch.cuda.empty_cache()
import gc
gc.collect()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 del model
#       2 torch.cuda.empty_cache()
#       3 import gc
#
# NameError: name 'model' is not defined

# %%
torch.cuda.empty_cache()
gc.collect()
# Out:
# 0
